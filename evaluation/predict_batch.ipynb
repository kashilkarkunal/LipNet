# %%
from lipnet.lipreading.videos import Video
from lipnet.lipreading.visualization import show_video_subtitle
from lipnet.core.decoders import Decoder
from lipnet.lipreading.helpers import labels_to_text
from lipnet.utils.spell import Spell
from lipnet.model2 import LipNet
from keras.optimizers import Adam
from keras import backend as K
import numpy as np
import sys
import os
import glob
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(55)

CURRENT_PATH = os.getcwd()

FACE_PREDICTOR_PATH = os.path.join(CURRENT_PATH,'..','common','predictors','shape_predictor_68_face_landmarks.dat')

PREDICT_GREEDY      = False
PREDICT_BEAM_WIDTH  = 200
PREDICT_DICTIONARY  = os.path.join(CURRENT_PATH,'..','common','dictionaries','grid.txt')

lipnet = None
adam = None
spell = None
decoder = None

def predict(weight_path, video):
    global lipnet
    global adam
    global spell
    global decoder

    if lipnet is None:
        lipnet = LipNet(img_c=3, img_w=100, img_h=50, frames_n=75,
                        absolute_max_string_len=32, output_size=28)

        adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

        lipnet.model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=adam)
        lipnet.model.load_weights(weight_path)

        spell = Spell(path=PREDICT_DICTIONARY)
        decoder = Decoder(greedy=PREDICT_GREEDY, beam_width=PREDICT_BEAM_WIDTH,
                          postprocessors=[labels_to_text, spell.sentence])

    X_data       = np.array([video.data]).astype(np.float32) / 255
    input_length = np.array([len(video.data)])
    try:
        y_pred         = lipnet.predict(X_data)
        result         = decoder.decode(y_pred, input_length)[0]

        show_video_subtitle(video.face, result)
        f = open("results.txt","a+")
        f.write(result)
        f.write('\n')
        f.close()
        print(result)
    except:
        pass

def predicts(weight_path, videos_path, absolute_max_string_len=32, output_size=28):
    videos = []
    i = 0
    for video_path in glob.glob(os.path.join(videos_path, '*')):
        f = open("results.txt","a+")
        f.write(video_path.split('/')[-1])
        f.write(' : ')
        f.close()
        predict(weight_path, load(video_path))

def load(video_path):
#     print("\n[{}]\nLoading data from disk...".format(video_path))
    print(video_path.split('/')[-1], "\n")
    video = Video(vtype='face', face_predictor_path=FACE_PREDICTOR_PATH)
    if os.path.isfile(video_path):
        video.from_video(video_path)
    else:
        video.from_frames(video_path)
    return video

# %%
path = os.getcwd()
vidpath = os.path.join(path,"..","datasets","s1")
weightpath = os.path.join(path,"models","overlapped-weights368.h5")
predicts(weightpath, vidpath)
# Out:
# lwiy6n.mpg
# /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# WARNING:tensorflow:From /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1062: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1044: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1008: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/matplotlib/figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# lay white in y six now
# lrak7s.mpg
#
# lay red at k seven soon
# lrbr5s.mpg
#
# lay red by r five soon
# pbwx2p.mpg
#
# place blue with x two please
# sbit2n.mpg
#
# set blue in t two now
# bgbu3s.mpg
#
# bin green by u three soon
# sbia3a.mpg
#
# set blue in a three again
# pwic8n.mpg
#
# place white in c eight now
# pwip6n.mpg
#
# place white in p six now
# bbaz4n.mpg
#
# bin blue at z four now
# srbu8p.mpg
#
# set red by u eight please
# prii8p.mpg
#
# place red in i eight please
# sgai8p.mpg
#
# set green at i eight please
# bwam9s.mpg
#
# bin white at m nine soon
# prac6n.mpg
#
# place red at c six now
# prwkzp.mpg
#
# place red with k zero please
# sgwd2p.mpg
#
# set green with d two please
# lbwe6p.mpg
#
# lay blue with e six please
# bbwg2p.mpg
#
# bin blue with g two please
# bris5a.mpg
#
# bin red in s five again
# lwik9s.mpg
# /datasets/home/59/359/a2jain/.local/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# lay white in k nine soon
# lrwr9s.mpg
#
# lay red with r nine soon
# brif4n.mpg
#
# bin red in f four now
# sran9s.mpg
#
# brbazp.mpg
#
# bin red by n zero please
# lrid9s.mpg
#
# lay red at d nine soon
# pbav3s.mpg
#
# place blue at v three soon
# lgiz4p.mpg
#
# lay green in z four please
# sbbn7s.mpg
#
# set blue by h seven soon
# bgwu6n.mpg
#
# bin green with u six now
# pgby4n.mpg
#
# place green by y four now
# pbwj4p.mpg
#
# place blue with j four please
# lgwazp.mpg
#
# lay green with a zero please
# pbai4n.mpg
#
# place blue at i four now
# sgio6n.mpg
#
# set green in o six now
# lwaz1s.mpg
#
# lay white at z one soon
# priv6p.mpg
#
# place red in v six please
# swbi6p.mpg
#
# set white by i six please
# sgav6p.mpg
#
# set green at v six please
# pbbv9a.mpg
#
# place blue by v nine again
# pwaq2p.mpg
#
# place white at q two please
# pwaj9a.mpg
#
# place white at j nine again
# prwq2n.mpg
#
# place red with q two now
# sbwb2n.mpg
#
# set blue with b two now
# lbax9s.mpg
#
# lay blue at x nine soon
# lrae4p.mpg
#
# lay red at e four please
# lbak3a.mpg
#
# lay blue at k three again
# sbinzp.mpg
#
# set blue in n zero please
# lwbl8p.mpg
#
# lay white by l eight please
# lbbr1a.mpg
#
# lay blue by r one again
# pgbr3a.mpg
#
# place green by r three again
# lbiqzn.mpg
#
# lay blue in q zero now
# lgil7a.mpg
#
# lay green in l seven again
# briz8p.mpg
#
# bin red in z eight please
# sria7s.mpg
#
# set red in a seven soon
# bgin3a.mpg
#
# bin green in n three again
# lgif1s.mpg
#
# lay green in f one soon
# pgwy8n.mpg
#
# place green with y eight now
# sbig5s.mpg
#
# set blue in g five soon
# bbwtzp.mpg
#
# bin blue with t zero please
# pwwy5a.mpg
#
# place white with y five again
# lgir8n.mpg
#
# lay green in r eight now
# sbbh5a.mpg
#
# set blue by h five again
# pbbjzp.mpg
#
# place blue by j zero please
# lbwk8n.mpg
#
# lay blue with k eight now
# lrbl3a.mpg
#
# lay red by l three again
# pwwk7a.mpg
#
# place white with k seven again
# sgiv3a.mpg
#
# set green in v three again
# srbh8n.mpg
#
# set red by h eight now
# lwir5a.mpg
#
# lay white in r five again
# sbwo3a.mpg
#
# set blue with o three again
# swwj1a.mpg
#
# set white with j one again
# pbap1a.mpg
#
# place blue at p one again
# bgat8n.mpg
#
# bin green at t eight now
# brwa4p.mpg
#
# pgay3a.mpg
#
# place green at y three again
# pbbc5s.mpg
#
# place blue by c five soon
# lbay1a.mpg
#
# lay blue at y one again
# bwat5a.mpg
#
# bin white at t five again
# bgaa9a.mpg
#
# bin green at a nine again
# bbir9a.mpg
#
# bin blue in r nine again
# pbwp7s.mpg
#
# place blue with p seven soon
# pbwc9s.mpg
#
# place blue with c nine soon
# bgan6p.mpg
#
# bin green at n six please
# lwbs2p.mpg
#
# lay white by s two please
# pgbk6n.mpg
#
# place green by k six now
# lbbk4n.mpg
#
# lay blue by k four now
# praj2p.mpg
#
# place red at j two please
# sgwx3s.mpg
#
# set green with x three soon
# srbo2n.mpg
#
# set red by o two now
# sbwh9a.mpg
#
# set blue with h nine again
# lbwy7s.mpg
#
# lay blue with y seven soon
# lrie1a.mpg
#
# lay red in e one again
# srao1a.mpg
#
# set red at u one again
# sbaa6p.mpg
#
# set blue at a six please
# lgwm8p.mpg
#
# lay green with m eight please
# pgak5a.mpg
#
# place green at k five again
# lrws1a.mpg
#
# lay red with s one again
# swib3s.mpg
#
# set white in b three soon
# brbm8p.mpg
#
# bin red by m eight please
# swau9s.mpg
#
# set white at u nine soon
# pwbx8n.mpg
#
# place white by x eight now
# lwazzn.mpg
#
# lay white at z zero now
# pbiu9s.mpg
#
# place blue in u nine soon
# bwbg8n.mpg
#
# bin white by g eight now
# srwo7s.mpg
#
# set red with o seven soon
# lbiq1s.mpg
#
# lay blue in q one soon
# lbby2n.mpg
#
# lay blue by y two now
# sgwj5s.mpg
#
# set green with j five soon
# prap5s.mpg
#
# place red at p five soon
# bwbt6n.mpg
#
# bin white by t six now
# bbil2n.mpg
#
# bin blue in l two now
# bwba7a.mpg
#
# bin white by a seven again
# pgiq3s.mpg
#
# place green in q three soon
# lray5s.mpg
#
# lay red at y five soon
# lgbm4p.mpg
#
# lay green by m four please
# lbad8p.mpg
#
# lay blue at d eight please
# pbbp2n.mpg
#
# place blue by p two now
# prwd7a.mpg
#
# place red with d seven again
# srbb7a.mpg
#
# set red by b seven again
# lgifzn.mpg
#
# lay green in f zero now
# srab1s.mpg
#
# set red at b one soon
# pwby1a.mpg
#
# place white by y one again
# bgia4p.mpg
#
# bin green in a four please
# bwwn8p.mpg
#
# bin white with n eight please
# bwam8n.mpg
#
# bin white at m eight now
# prac7s.mpg
#
# place red at c seven soon
# bwwu3a.mpg
#
# bin white with u three again
# lrbzzp.mpg
#
# lay red by z zero please
# srwv3a.mpg
#
# set red with v three again
# sran8n.mpg
#
# set red at n eight now
# lbwr5a.mpg
#
# lay blue with r five again
# swio3a.mpg
#
# set white in o three again
# brif5s.mpg
#
# bin red in f five soon
# pgwlzn.mpg
#
# place green with l zero now
# lwar8p.mpg
#
# lay white at r eight please
# bwaa1s.mpg
#
# bin white at a one soon
# lrwr8n.mpg
#
# lay red with r eight now
# sban5a.mpg
#
# set blue at n five again
# sgbjzn.mpg
#
# set green by j zero now
# lwik8n.mpg
#
# lay white in k eight now
# srah7a.mpg
#
# set red in h seven again
# pgwr7a.mpg
#
# place green with r seven again
# swih9a.mpg
#
# set white in h nine again
# lrbr4n.mpg
#
# lay red by r four now
# lwiy7s.mpg
#
# lay white in y seven soon
# lrak6n.mpg
#
# lay red at k six now
# bwbn4p.mpg
#
# bin white by n four please
# pwip7s.mpg
#
# place white in p seven soon
# bbaz5s.mpg
#
# bin blue at z five soon
# pwic9s.mpg
#
# place white in c nine soon
# bgbh6p.mpg
#
# bin green by h six please
# bgbu2n.mpg
#
# bin green by u two now
# sbit3s.mpg
#
# set blue in t three soon
# bgau1a.mpg
#
# bin green at u one again
# pwax7a.mpg
#
# place white at x seven again
# bgbozp.mpg
#
# bin green by o zero please
# sbwb3s.mpg
#
# set blue with b three soon
# lbax8n.mpg
#
# lay blue in x eight now
# lgis1a.mpg
#
# lay green in s one again
# sbig4n.mpg
#
# set blue in g four now
# lbbe2p.mpg
#
# lay blue by e two please
# pgwy9s.mpg
#
# place green with y nine soon
# srbi1a.mpg
#
# set red by i one again
# sria6n.mpg
#
# set red in a six now
# lriq9a.mpg
#
# lay red in q nine again
# pgby5s.mpg
#
# place green by y five soon
# lbid5a.mpg
#
# lay blue in d five again
# lwafzp.mpg
#
# lay white at f zero please
# bgwu7s.mpg
#
# bin green with u seven soon
# pwbd8p.mpg
#
# place white by d eight please
# pbac3a.mpg
#
# place blue at c three again
# lrwfzn.mpg
#
# lay red with f zero now
# sbbn6n.mpg
#
# set blue by n six now
# pbav2n.mpg
#
# place blue at v two now
# lrid8n.mpg
#
# lay red in d eight now
# pgid7a.mpg
#
# place green in d seven again
# bwag7a.mpg
#
# bin white at g seven again
# prwq3s.mpg
#
# place red with q three soon
# sgio7s.mpg
#
# set green in o seven soon
# pbai5s.mpg
#
# place blue at i five soon
# bbif1a.mpg
#
# bin blue in f one again
# pbwc8n.mpg
#
# place blue with c eight now
# prbd3a.mpg
#
# place red by d three again
# pbwp6n.mpg
#
# place blue with p six now
# lgas4p.mpg
#
# lay green at s four please
# srabzn.mpg
#
# set red at b zero now
# bwaazn.mpg
#
# bin white at a zero now
# pgwl1s.mpg
#
# place green with l one soon
# bwwbzp.mpg
#
# bin white with b zero please
# lbwy6n.mpg
#
# lay blue with y six now
# sgbj1s.mpg
#
# set green by j one soon
# srbo3s.mpg
